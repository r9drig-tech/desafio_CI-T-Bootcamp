# %% [markdown]
# # 📊 01 — Análise Exploratória de Dados
# > Bootcamp CI&T — Do Prompt ao Agente | Rodrigo Salgado

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append('..')
sns.set_theme(style='darkgrid')
print('✅ Bibliotecas carregadas!')

# %% [markdown]
# ## 📥 1. Carregamento dos Dados

# %%
from src.ingestion.api_extractor import APIExtractor
extractor = APIExtractor(
    base_url='https://api.bcb.gov.br/dados/serie',
    endpoint='/bcdata.sgs.1/dados',
    params={'formato': 'json', 'dataInicial': '01/01/2023'}
)
df = extractor.extract()
df.head()

# %% [markdown]
# ## 🔍 2. Visão Geral

# %%
print('Shape:', df.shape)
print('Nulos:\n', df.isnull().sum())
df.describe().round(2)

# %% [markdown]
# ## 📈 3. Distribuições

# %%
num_cols = df.select_dtypes(include='number').columns
for col in num_cols:
    plt.figure(figsize=(10,4))
    sns.histplot(df[col].dropna(), kde=True, color='steelblue')
    plt.title(f'Distribuição: {col}')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 🔥 4. Correlação

# %%
corr = df.select_dtypes(include='number').corr()
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Mapa de Correlação')
plt.show()

# %%
df.to_csv('../data/raw/dados_eda.csv', index=False)
print(f'✅ Salvo! Shape: {df.shape}')
